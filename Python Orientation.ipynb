# %% [markdown]
# <a href="https://colab.research.google.com/github/Charyoe/ML-with-Python-Bootcamp/blob/main/ML_Bootcamp_Work.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Example of a String

# %%
Greetings = "What up, doctor"

print (Greetings)
# Out:
# What up, doctor

# %% [markdown]
# Example of addition

# %%
A=2
B=3
C=A+B
print(C)
# Out:
# 5
